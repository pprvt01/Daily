# %% [markdown]
# <a href="https://colab.research.google.com/github/pprvt01/Daily/blob/master/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Workers instrument Data.v1i.yolov8
# Out:
# /content/drive/MyDrive/Colab Notebooks/Workers instrument Data.v1i.yolov8

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Workers instrument Data.v1i.yolov8
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/Colab Notebooks/Workers instrument Data.v1i.yolov8
# New https://pypi.org/project/ultralytics/8.3.136 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image, display

# %cd /content/drive/MyDrive/Colab Notebooks

model=YOLO('yolo11n-seg.pt')
results=model('child.jpg')
results[0].show
# Save the results image
results[0].save(filename='output.jpg')  # Save the image with detections

# Display the saved image in Colab
display(Image(filename='output.jpg'))
# Out:
# /content/drive/MyDrive/Colab Notebooks
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/child.jpg: 352x640 6 persons, 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)

# %%
from ultralytics import YOLO

# %cd /content/drive/MyDrive/Colab Notebooks

model=YOLO('yolo11n-seg.pt')
results=model('personwithdogs.mp4', save=True)
# Out:
# /content/drive/MyDrive/Colab Notebooks
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/470) /content/drive/MyDrive/Colab Notebooks/personwithdogs.mp4: 384x640 2 persons, 4 dogs, 1 potted plant, 88.5ms
# video 1/1 (frame 2/470) /content/drive/MyDrive/Colab Notebooks/personwithdogs.mp4: 384x640 2 persons, 5 dogs, 1 potted plant, 31.7ms
# ...

# %%
# !pip install roboflow


from roboflow import Roboflow
rf = Roboflow(api_key="TfJCvgcP6yKE8dFA0TzA")
project = rf.workspace("pprvt").project("ppe-dataset-m4ypy")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ppe-dataset-1 in yolov11:: 100%|██████████| 704/704 [00:00<00:00, 8015.57it/s]

# %%
dataset.location
# Out:
# '/content/ppe-dataset-1'

# %%
# !yolo task=detect mode=train model="yolo11n.pt" data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.3.136 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
